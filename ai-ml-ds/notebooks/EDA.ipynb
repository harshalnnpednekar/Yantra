# %% [markdown]
# # Yantra Engine - EDA Starter
# This notebook provides a starting point for Exploratory Data Analysis for your hackathon project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Load Data
# Replace 'data.csv' with your actual dataset.

# %%
# df = pd.read_csv('../data/data.csv')
# df.head()

# %% [markdown]
# ## 2. Basic Statistics

# %%
# df.describe()
# df.info()

# %% [markdown]
# ## 3. Visualizations

# %%
# sns.pairplot(df)
